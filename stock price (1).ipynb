# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

df = pd.read_csv("C:\\Users\\rishika singh\\Downloads\\RELIANCE (2).csv")
df.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50  251.70
# 1  2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30  271.85
# 2  2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65  286.75
# 3  2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00  293.50
# 4  2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00  314.50
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  251.70  249.37   4456424  1.111319e+14     NaN                 NaN
# 1  271.85  263.52   9487878  2.500222e+14     NaN                 NaN
# 2  282.50  274.79  26833684  7.373697e+14     NaN                 NaN
# 3  294.35  295.45  15682286  4.633254e+14     NaN                 NaN
# 4  314.55  308.91  19870977  6.138388e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.shape
# Out:
# (5075, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5075 non-null   object
#  1   Symbol              5075 non-null   object
#  2   Series              5075 non-null   object
#  3   Prev Close          5075 non-null   float64
#  4   Open                5075 non-null   float64
#  5   High                5075 non-null   float64
#  6   Low                 5075 non-null   float64
#  7   Last                5075 non-null   float64
#  8   Close               5075 non-null   float64
#  9   VWAP                5075 non-null   float64
#  10  Volume              5075 non-null   int64
#  11  Turnover            5075 non-null   float64
#  12  Trades              2225 non-null   float64
#  13  Deliverable Volume  4561 non-null   float64
#  14  %Deliverble         4561 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 594.9+ KB

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5075.000000  5075.000000  5075.000000  5075.000000  5075.000000
# mean    965.972099   967.397271   981.117429   952.283685   966.024808
# std     541.288654   542.662284   552.104362   530.774975   541.060224
# min     203.200000   205.500000   219.500000   197.150000   203.300000
# 25%     550.175000   554.000000   561.875000   545.000000   551.400000
# 50%     919.950000   920.100000   931.000000   909.300000   919.350000
# 75%    1138.900000  1142.775000  1160.925000  1118.200000  1137.750000
# max    3220.850000  3298.000000  3298.000000  3141.300000  3223.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  5075.000000  5075.000000  5.075000e+03  5.075000e+03  2.225000e+03
# mean    966.214729   966.761762  5.130275e+06  4.939702e+14  1.220797e+05
# std     541.236031   541.271968  4.155610e+06  5.184849e+14  9.573483e+04
# min     203.200000   212.290000  5.282000e+04  4.295543e+12  2.991000e+03
# 25%     551.225000   551.505000  2.778337e+06  2.139267e+14  6.981400e+04
# 50%     920.000000   920.170000  4.085150e+06  3.514797e+14  9.556100e+04
# 75%    1139.325000  1140.035000  6.215759e+06  6.087882e+14  1.417590e+05
# max    3220.850000  3197.750000  6.523089e+07  8.835030e+15  1.194059e+06
#
#        Deliverable Volume  %Deliverble
# count        4.561000e+03  4561.000000
# mean         2.163814e+06     0.441044
# std          1.776589e+06     0.144237
# min          2.909700e+04     0.076300
# 25%          1.161475e+06     0.329900
# 50%          1.743995e+06     0.457500
# 75%          2.587743e+06     0.548300
# max          3.495888e+07     0.978300

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5075 non-null   object
#  1   Symbol              5075 non-null   object
#  2   Series              5075 non-null   object
#  3   Prev Close          5075 non-null   float64
#  4   Open                5075 non-null   float64
#  5   High                5075 non-null   float64
#  6   Low                 5075 non-null   float64
#  7   Last                5075 non-null   float64
#  8   Close               5075 non-null   float64
#  9   VWAP                5075 non-null   float64
#  10  Volume              5075 non-null   int64
#  11  Turnover            5075 non-null   float64
#  12  Trades              2225 non-null   float64
#  13  Deliverable Volume  4561 non-null   float64
#  14  %Deliverble         4561 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 594.9+ KB

# %%
stockprice_one_year = df[(df['Date']>'2000-03-31')&(df['Date']<'2001-04-01')]
stockprice_one_year
# Out:
#            Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 62   2000-04-03  RELIANCE     EQ      316.45  327.65  333.70  318.10  328.00
# 63   2000-04-04  RELIANCE     EQ      328.60  326.00  326.00  302.35  302.35
# 64   2000-04-05  RELIANCE     EQ      302.35  303.40  312.00  278.25  301.00
# 65   2000-04-06  RELIANCE     EQ      302.25  303.00  326.45  302.55  326.45
# 66   2000-04-07  RELIANCE     EQ      326.15  329.80  352.25  329.80  352.25
# ..          ...       ...    ...         ...     ...     ...     ...     ...
# 308  2001-03-26  RELIANCE     EQ      379.55  380.00  386.60  376.10  384.40
# 309  2001-03-27  RELIANCE     EQ      384.20  383.00  394.40  381.70  390.00
# 310  2001-03-28  RELIANCE     EQ      390.70  395.00  405.00  393.60  404.10
# 311  2001-03-29  RELIANCE     EQ      402.00  401.25  405.85  394.00  395.00
# 312  2001-03-30  RELIANCE     EQ      396.45  394.10  396.70  386.65  390.80
#
#       Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 62   328.60  325.80  21353020  6.956770e+14     NaN                 NaN
# 63   302.35  310.24  13530488  4.197703e+14     NaN                 NaN
# 64   302.25  296.71  25186375  7.473067e+14     NaN                 NaN
# 65   326.15  312.99  16239068  5.082674e+14     NaN                 NaN
# 66   352.25  347.35  11686144  4.059225e+14     NaN                 NaN
# ..      ...     ...       ...           ...     ...                 ...
# 308  384.20  383.11   1771673  6.787425e+13     NaN                 NaN
# 309  390.70  389.83   2935850  1.144484e+14     NaN                 NaN
# 310  402.00  399.38   2667459  1.065335e+14     NaN                 NaN
# 311  396.45  399.47   3813078  1.523229e+14     NaN                 NaN
# 312  389.55  391.98   2456373  9.628564e+13     NaN                 NaN
#
#      %Deliverble
# 62           NaN
# 63           NaN
# 64           NaN
# 65           NaN
# 66           NaN
# ..           ...
# 308          NaN
# 309          NaN
# 310          NaN
# 311          NaN
# 312          NaN
#
# [251 rows x 15 columns]

# %%
stockprice_one_year.isnull().sum()
# Out:
# Date                    0
# Symbol                  0
# Series                  0
# Prev Close              0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# VWAP                    0
# Volume                  0
# Turnover                0
# Trades                251
# Deliverable Volume    251
# %Deliverble           251
# dtype: int64

# %%
stockprice_one_year.describe()
# Out:
#        Prev Close        Open        High         Low        Last       Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   347.337052  347.832072  353.747211  342.008566  347.574104  347.628287
# std     31.285379   31.421375   31.890813   30.813561   31.209189   31.336903
# min    285.850000  286.000000  294.700000  278.250000  286.100000  285.850000
# 25%    328.475000  327.825000  334.200000  322.775000  328.550000  328.875000
# 50%    339.400000  340.900000  345.900000  336.400000  339.250000  339.400000
# 75%    363.450000  363.000000  370.425000  359.550000  363.425000  363.950000
# max    438.200000  440.000000  451.000000  421.000000  436.000000  438.200000
#
#              VWAP        Volume      Turnover  Trades  Deliverable Volume  \
# count  251.000000  2.510000e+02  2.510000e+02     0.0                 0.0
# mean   348.137331  6.118166e+06  2.149348e+14     NaN                 NaN
# std     31.490247  4.502550e+06  1.596461e+14     NaN                 NaN
# min    287.730000  2.252130e+05  7.010414e+12     NaN                 NaN
# 25%    328.700000  3.265574e+06  1.062170e+14     NaN                 NaN
# 50%    341.360000  4.730779e+06  1.619632e+14     NaN                 NaN
# 75%    364.890000  7.502576e+06  2.675242e+14     NaN                 NaN
# max    438.300000  2.954759e+07  1.041727e+15     NaN                 NaN
#
#        %Deliverble
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
stockprice_one_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries, 62 to 312
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                251 non-null    object
#  1   Symbol              251 non-null    object
#  2   Series              251 non-null    object
#  3   Prev Close          251 non-null    float64
#  4   Open                251 non-null    float64
#  5   High                251 non-null    float64
#  6   Low                 251 non-null    float64
#  7   Last                251 non-null    float64
#  8   Close               251 non-null    float64
#  9   VWAP                251 non-null    float64
#  10  Volume              251 non-null    int64
#  11  Turnover            251 non-null    float64
#  12  Trades              0 non-null      float64
#  13  Deliverable Volume  0 non-null      float64
#  14  %Deliverble         0 non-null      float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 31.4+ KB

# %%
p1 = df['Prev Close'].plot(c='green')
stockprice_one_year['Prev Close'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['Open'].plot(c='green')
stockprice_one_year['Open'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['High'].plot(c='green')
stockprice_one_year['High'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['Low'].plot(c='green')
stockprice_one_year['Low'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['Last'].plot(c='green')
stockprice_one_year['Last'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['Close'].plot(c='green')
stockprice_one_year['Close'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
p1 = df['VWAP'].plot(c='green')
stockprice_one_year['VWAP'].plot(ax=p1,c='red')
# Out:
# <Axes: >

# %%
plt.plot(df['Open'])

# %%
plt.style.use('fivethirtyeight')
plt.plot(df['Open'])

# %%
stockprice_one_year.plot(x="Date", y=["Low","High","Close","Open","Last"],color = ['r','g','k','b','y'], figsize = [25,15])
# Out:
# <Axes: xlabel='Date'>

# %%
stockprice_one_year.plot(x="Date", y=["Low","High"],color = ['r','b'], figsize = [25,15])
plt.show()

# %%
stockprice_one_year.plot(x="Date", y=["Low","High"],color = ['r','b'], figsize = [25,15])
plt.fill_between(stockprice_one_year['Date'], stockprice_one_year['Low'], stockprice_one_year['High'], color='k',alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.boxplot(stockprice_one_year[['Close','High','Open','Low','VWAP']])
plt.show()

# %%
data = df[['Date','Open','High','Low','Volume','VWAP']]
df.set_index("Date", drop=False, inplace=True)
df.Close.plot(figsize=(14, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5075 non-null   object
#  1   Open    5075 non-null   float64
#  2   High    5075 non-null   float64
#  3   Low     5075 non-null   float64
#  4   Volume  5075 non-null   int64
#  5   VWAP    5075 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 238.0+ KB

# %%
df.reset_index(drop=True, inplace=True)
lag_features = ["Open","High","Low","VWAP"]
window1 = 3
window2 = 7

df_rolled_3d = df[lag_features].rolling(window=window1, min_periods=0)
df_mean_3d = df_rolled_3d.mean().shift(1).reset_index().astype(np.float32)

df_rolled_7d = df[lag_features].rolling(window=window2, min_periods=0)
df_std_7d = df_rolled_7d.std().shift(1).reset_index().astype(np.float32)

for feature in lag_features:
    df[f"{feature}_mean_lag{window1}"] = df_mean_3d[feature].astype('float32')
    df[f"{feature}_std_lag{window2}"] = df_std_7d[feature].astype('float32')

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.set_index("Date", drop=False, inplace=True)
df.head()
# Out:
#                   Date    Symbol Series  Prev Close    Open    High     Low  \
# Date
# 2000-01-03  2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50
# 2000-01-04  2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30
# 2000-01-05  2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65
# 2000-01-06  2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00
# 2000-01-07  2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00
#
#               Last   Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2000-01-03  251.70  251.70  249.37   4456424  1.111319e+14     NaN
# 2000-01-04  271.85  271.85  263.52   9487878  2.500222e+14     NaN
# 2000-01-05  286.75  282.50  274.79  26833684  7.373697e+14     NaN
# 2000-01-06  293.50  294.35  295.45  15682286  4.633254e+14     NaN
# 2000-01-07  314.50  314.55  308.91  19870977  6.138388e+14     NaN
#
#             Deliverable Volume  %Deliverble
# Date
# 2000-01-03                 NaN          NaN
# 2000-01-04                 NaN          NaN
# 2000-01-05                 NaN          NaN
# 2000-01-06                 NaN          NaN
# 2000-01-07                 NaN          NaN

# %%
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
df["month"] = df.Date.dt.month
df["day"] = df.Date.dt.day
df["day_of_week"] = df.Date.dt.dayofweek
df.head()
# Out:
#                  Date    Symbol Series  Prev Close    Open    High     Low  \
# Date
# 2000-01-03 2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50
# 2000-01-04 2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30
# 2000-01-05 2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65
# 2000-01-06 2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00
# 2000-01-07 2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00
#
#               Last   Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2000-01-03  251.70  251.70  249.37   4456424  1.111319e+14     NaN
# 2000-01-04  271.85  271.85  263.52   9487878  2.500222e+14     NaN
# 2000-01-05  286.75  282.50  274.79  26833684  7.373697e+14     NaN
# 2000-01-06  293.50  294.35  295.45  15682286  4.633254e+14     NaN
# 2000-01-07  314.50  314.55  308.91  19870977  6.138388e+14     NaN
#
#             Deliverable Volume  %Deliverble  month  day  day_of_week
# Date
# 2000-01-03                 NaN          NaN      1    3            0
# 2000-01-04                 NaN          NaN      1    4            1
# 2000-01-05                 NaN          NaN      1    5            2
# 2000-01-06                 NaN          NaN      1    6            3
# 2000-01-07                 NaN          NaN      1    7            4

# %%
df = df.drop(columns=['Symbol'])
df = df.drop(columns=['Series'])

# %%
df_train = df[df.Date < "2001"]
df_valid = df[df.Date >= "2001"]
df_valid.shape
# Out:
# (4825, 18)

# %%
import tensorflow
from sklearn.preprocessing import MinMaxScaler
df_train.head().T
# Out:
# Date                         2000-01-03           2000-01-04  \
# Date                2000-01-03 00:00:00  2000-01-04 00:00:00
# Symbol                         RELIANCE             RELIANCE
# Series                               EQ                   EQ
# Prev Close                       233.05                251.7
# Open                              237.5                258.4
# High                              251.7               271.85
# Low                               237.5                251.3
# Last                              251.7               271.85
# Close                             251.7               271.85
# VWAP                             249.37               263.52
# Volume                          4456424              9487878
# Turnover              111131914445000.0    250022190690000.0
# Trades                              NaN                  NaN
# Deliverable Volume                  NaN                  NaN
# %Deliverble                         NaN                  NaN
# month                                 1                    1
# day                                   3                    4
# day_of_week                           0                    1
#
# Date                         2000-01-05           2000-01-06  \
# Date                2000-01-05 00:00:00  2000-01-06 00:00:00
# Symbol                         RELIANCE             RELIANCE
# Series                               EQ                   EQ
# Prev Close                       271.85                282.5
# Open                             256.65                289.0
# High                              287.9                300.7
# Low                              256.65                289.0
# Last                             286.75                293.5
# Close                             282.5               294.35
# VWAP                             274.79               295.45
# Volume                         26833684             15682286
# Turnover              737369727570000.0    463325404090000.0
# Trades                              NaN                  NaN
# Deliverable Volume                  NaN                  NaN
# %Deliverble                         NaN                  NaN
# month                                 1                    1
# day                                   5                    6
# day_of_week                           2                    3
#
# Date                         2000-01-07
# Date                2000-01-07 00:00:00
# Symbol                         RELIANCE
# Series                               EQ
# Prev Close                       294.35
# Open                              295.0
# High                              317.9
# Low                               293.0
# Last                              314.5
# Close                            314.55
# VWAP                             308.91
# Volume                         19870977
# Turnover              613838765740000.0
# Trades                              NaN
# Deliverable Volume                  NaN
# %Deliverble                         NaN
# month                                 1
# day                                   7
# day_of_week                           4

# %%
y_train = df_train["close"]
scaler=MinMaxScaler(feature_range=(0,1))
y_train1=scaler.fit_transform(np.array(df_train['close']).reshape(-1,1))
y_trainn = df_train["close"].to_numpy().reshape(-1,1)

y_valid = df_valid["close"]
scaler1=MinMaxScaler(feature_range=(0,1))
y_valid1=scaler1.fit_transform(np.array(df_valid['close']).reshape(-1,1))
y_validn = df_valid["close"].to_numpy().reshape(-1,1)

x_train = df_train.drop(columns=["close"])
x_train1 = x_train.drop("Date", axis=1)
x_train1 = (x_train1-x_train1.min())/(x_train1.max()-x_train1.min())
x_train2 = pd.concat((x_train1, x_train.Date), 1)

x_valid = df_valid.drop(columns=["close"])
x_valid1 = x_valid.drop("Date", axis=1)
x_valid1 = (x_valid1-x_valid1.min())/(x_valid1.max()-x_valid.min())
x_valid2 = pd.concat((x_valid1, x_valid.Date), 1)

x_train3 = x_train2.drop(columns=['Date']).to_numpy()
x_valid3 = x_valid2.drop(columns=['Date']).to_numpy()

# %%
y_train1 = y_train1.reshape(-1,1)
y_valid1 = y_valid1.reshape(-1,1)

# %%
import xgboost as xgb
import sklearn
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
xgb = XGBRegressor(n_estimators=1000,learning_rate=0.01)
xgb

xgb.fit(x_train3,y_train1,eval_set=[(x_train3,y_train1),(x_valid3,y_valid1)],early_stopping_rounds=100,verbose=True)

# %%
plt.figure(figsize=(12,8))
feature_importance = plot_importance(xgb, height=0.9)
feature_importance

# %%
predicted_results_v = xgb.pridict(x_valid3)
predicted_results_t = xgb.pridict(x_train3)
predicted_results_v = predicted_results_v.reshape(-1, 1)
predicted_results_t = predicted_results_t.reshape(-1, 1)
predicted_results_v = scaler1.inverse_transform(predicted_results_v)
predicted_results_t = scaler1.inverse_transform(predicted_results_t)

# %%
plt.figure(figsize=(20,15))
plt.plot(x_train2.index,list(y_trainn),label="actual price train",color='b')
plt.plot(x_train2.index,list(predicted_results_t),label="predicted Price train",color='r')
plt.plot(x_valid2.index,list(y_validn),label="actual price valid",color='m')
plt.plot(x_valid2.index,list(predicted_results_t),label="predicted Price valid",color='g')

plt.xlabel('Date')
plt.ylabel('Nifty 50 closing price')
plt.legend()
plt.show()

# %%
xgb = XGBRegressor(n_estimators=1000,learning_rate=0.0099,max_depth=15)
xgb

xgb.fit(x_train3,y_train1,eval_set=[(x_train3,y_train1),(x_valid3,y_valid1)],early_stopping_rounds=100,verbose=True)

# %%
predicted_results_v = xgb.pridict(x_valid3)
predicted_results_t = xgb.pridict(x_train3)
predicted_results_v = predicted_results_v.reshape(-1, 1)
predicted_results_t = predicted_results_t.reshape(-1, 1)
predicted_results_v = scaler1.inverse_transform(predicted_results_v)
predicted_results_t = scaler1.inverse_transform(predicted_results_t)

# %%
predicted_results_v = xgb.pridict(x_valid3)
predicted_results_t = xgb.pridict(x_train3)
predicted_results_v = predicted_results_v.reshape(-1, 1)
predicted_results_t = predicted_results_t.reshape(-1, 1)
predicted_results_v = scaler1.inverse_transform(predicted_results_v)
predicted_results_t = scaler1.inverse_transform(predicted_results_t)
